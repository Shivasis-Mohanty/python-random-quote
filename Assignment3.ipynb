# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivasis-Mohanty/python-random-quote/blob/master/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
GoT = ['Tony', 'Rocket', 'Scott', 'Steve', 'Rocket', 'Natasha', 'Tony']
mylist = list(dict.fromkeys(GoT))
print(mylist)
# Out:
# ['Tony', 'Rocket', 'Scott', 'Steve', 'Natasha']

# %%
def Remove(duplicate):
    final_list = []
    for num in duplicate:
        if num not in final_list:
            final_list.append(num)
    return final_list
duplicate = [2, 4, 10, 20, 5, 2, 20, 4]
print(Remove(duplicate))
# Out:
# [2, 4, 10, 20, 5]

# %%
l= [(90,69,56),(21,34,54)]
sum=[]
for i in l:
  add=0
  for j in i:
    add+= j
  sum.append(add)
print(l)
print(sum)
# Out:
# [(90, 69, 56), (21, 34, 54)]
# [215, 109]
