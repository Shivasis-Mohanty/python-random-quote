# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivasis-Mohanty/python-random-quote/blob/master/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
P = float (input("Enter the principal amount = "))
R = float (input("Enter the rate of intrest = "))
T = float (input("Enter the time = "))
SI = P*R*T
CI = P*(1+R)**T-P
print("Compound intrest is ",CI)
print("Simple intrest is ", SI)
# Out:
# Enter the principal amount = 56789
# Enter the rate of intrest = 2
# Enter the time = 4
# Compound intrest is  4543120.0
# Simple intrest is  454312.0

# %%
a = input("Enter your First name")
b = input("Enter your second name")
c = input("Enter your last name")
f= a+b+c
print("Full name is",f)
# Out:
# Enter your First nameShivasis
# Enter your second nameKumar
# Enter your last nameMohanty
# Full name is Shivasis Kumar Mohanty

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  password="yourpassword",
  database="mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-e6e4183e7ba0> in <module>()
# ----> 1 import mysql.connector
#       2
#       3 mydb = mysql.connector.connect(
#       4   host="localhost",
#       5   user="yourusername",
#
# ModuleNotFoundError: No module named 'mysql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
SUM= 5+5.5
x = 6.7
d = int (x)
print(SUM)
print(d)
# Out:
# 10.5
# 6

# %%
import math
x1 = float (input("Enter The value X1 "))
y1 = float (input("Enter The value Y1 "))
x2 = float (input("Enter The value X2 "))
y2 = float (input("Enter The value Y2 "))
d = math.sqrt ((x1-y1)**2+(x2-y2)**2)
print("Distance between two points is ",d)
# Out:
# Enter The value X1 3
# Enter The value Y1 4
# Enter The value X2 5
# Enter The value Y2 6
# Distance between two points is  1.4142135623730951
