# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivasis-Mohanty/python-random-quote/blob/master/Simplepythonprograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter your name: ");
age= int (input("Enter your age: "));
adress=input("Enter Your postal adress: ");
print(name)
print(age)
print(adress)
# Out:
# Enter your name: Shivasis
# Enter your age: 19
# Enter Your postal adress: Cuttack
# Shivasis
# 19
# Cuttack

# %%
Maths=int input(Enter your maths )
